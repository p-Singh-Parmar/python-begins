# %%
from PIL import Image

# %%
comp = Image.open('my_computer_image.jpg')

# %%
comp.show() #open image in in photos app

# %%
comp
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x331 at 0x15F5FC49460>

# %%
comp.size
# Out:
# (220, 331)

# %%
comp.filename
# Out:
# 'my_computer_image.jpg'

# %%
comp.format_description
# Out:
# 'JPEG (ISO 10918)'

# %%
# CROPPING IMAGE

# %%
comp.crop((0,0,200,200))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x15F5FF1F640>

# %%
snt = Image.open('Screenshot (9).png')

# %%
snt
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080 at 0x15F5FEE92B0>

# %%
snt.size
# Out:
# (1920, 1080)

# %%
x=1680
y=630

w=1919
h=840

# %%
san=snt.crop((x,y,w,h))

# %%
san
# Out:
# <PIL.Image.Image image mode=RGBA size=239x210 at 0x15F5FF36D90>

# %%
comp.paste(im=san, box=(-9,-1))

# %%
comp
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x331 at 0x15F5FC49460>

# %%
comp.resize((3000,900))
# Out:
# <PIL.Image.Image image mode=RGB size=3000x900 at 0x15F5FF36100>

# %%
comp.rotate(0)
# Out:
# <PIL.Image.Image image mode=RGB size=220x331 at 0x15F5FF36340>

# %%
comp.putalpha(50)

# %%
san.putalpha(175)

# %%
comp.paste(im=san,box=(0,0))

# %%
san
# Out:
# <PIL.Image.Image image mode=RGBA size=239x210 at 0x15F5FF36D90>

# %%
comp
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGBA size=220x331 at 0x15F5FC49460>

# %%
comp.save("mixed.png")
